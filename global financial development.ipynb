# %%
# importing the necessary libraries
import pandas as pd

# %% [markdown]
# ### Loading the Dataset

# %%
# reading the csv file and assigning it to a variable
global_financial_development = pd.read_csv("datasets/GFDDData.csv")

# %%
# loading the dataset
global_financial_development.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                       Indicator Name Indicator Code  1960  \
# 0                         5-bank asset concentration     GFDD.OI.06   NaN
# 1  Account at a formal financial institution (% a...     GFDD.AI.05   NaN
# 2     Account used for business purposes (% age 15+)     GFDD.AI.08   NaN
# 3  Account used to receive government payments (%...     GFDD.AI.09   NaN
# 4    Account used to receive remittances (% age 15+)     GFDD.AI.10   NaN
#
#    1961  1962  1963  1964  1965  ...     2009    2010      2011     2012  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  89.3635  83.133  86.66470  84.8274
# 1   NaN   NaN   NaN   NaN   NaN  ...      NaN     NaN   9.00501      NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...      NaN     NaN   2.71840      NaN
# ...

# %%
# getting information about the dataset
global_financial_development.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25038 entries, 0 to 25037
# Data columns (total 63 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    25038 non-null  object
#  1   Country Code    25038 non-null  object
#  2   Indicator Name  25038 non-null  object
#  3   Indicator Code  25038 non-null  object
#  4   1960            1477 non-null   float64
#  5   1961            1544 non-null   float64
#  6   1962            1604 non-null   float64
#  7   1963            1635 non-null   float64
#  8   1964            1707 non-null   float64
#  9   1965            1776 non-null   float64
#  10  1966            1817 non-null   float64
#  11  1967            1862 non-null   float64
#  12  1968            1882 non-null   float64
#  13  1969            1903 non-null   float64
#  14  1970            2191 non-null   float64
#  15  1971            2242 non-null   float64
#  16  1972            2294 non-null   float64
# ...

# %%
# getting a description of the dataset
global_financial_development.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  1.477000e+03  1.544000e+03  1.604000e+03  1.635000e+03  1.707000e+03
# mean   1.489747e+09  1.485669e+09  1.567131e+09  1.649022e+09  1.738145e+09
# std    2.063050e+10  2.092977e+10  2.218057e+10  2.312462e+10  2.447867e+10
# min    2.800000e-11 -6.869230e+00 -1.204930e+01  3.500000e-14 -1.159770e+01
# 25%    1.119360e+01  1.102010e+01  1.115287e+01  1.128380e+01  1.106555e+01
# 50%    4.822270e+01  4.259025e+01  4.203275e+01  4.251640e+01  4.107100e+01
# 75%    1.094200e+05  6.561440e+04  5.218250e+04  3.810000e+04  2.005680e+04
# max    5.500000e+11  5.700000e+11  6.100000e+11  6.400000e+11  6.900000e+11
#
#                1965          1966          1967          1968          1969  \
# count  1.776000e+03  1.817000e+03  1.862000e+03  1.882000e+03  1.903000e+03
# mean   1.823982e+09  1.955965e+09  2.040700e+09  2.194465e+09  2.361886e+09
# ...

# %%
# checking for empty fields in the dataset
global_financial_development.isnull().sum()
# Out:
# Country Name          0
# Country Code          0
# Indicator Name        0
# Indicator Code        0
# 1960              23561
#                   ...
# 2014              11966
# 2015              14664
# 2016              14781
# 2017              13392
# Unnamed: 62       25038
# Length: 63, dtype: int64

# %% [markdown]
# Since there exist some fields that are empty, we'll drop those fields.

# %%
# dropping the empty fields
